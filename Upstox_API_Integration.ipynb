# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish-281/DOcs1/blob/main/Upstox_API_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install upstox-python-sdk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for upstox-python-sdk: filename=upstox_python_sdk-2.14.0-py3-none-any.whl size=453369 sha256=4fbc025062aa9706ce532fb5c9eed8cc61b65be3c7f1f100b8fdfc613f7a4318
#   Stored in directory: /root/.cache/pip/wheels/56/96/ea/8c5457645ffe5d35f6ed26978932acc560e3daf2d4cbdcbffa
# ...
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6477 sha256=f73e06f1795f3d85bb38b473309ce0995a8f5d1033389a0641572c42a805e63a
#   Stored in directory: /root/.cache/pip/wheels/e0/01/df/bd20df409bd81f8b99e6cd343c5f49731dc0a20eefefdafae0
# Successfully built upstox-python-sdk uuid
# ...

# %%
client_id = 'de2bff0c-c5cc-4752-a808-46759419dc88'
secret_key = 'jd4wmhwjgj'
redirect_uri = 'https://145.5.5.6:6000/'

# %%
url = f'https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id={client_id}&redirect_uri={redirect_uri}'
url
# Out:
# 'https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=de2bff0c-c5cc-4752-a808-46759419dc88&redirect_uri=https://145.5.5.6:6000/'

# %%
code = 'U4C93M'

# %%
import requests

url = 'https://api.upstox.com/v2/login/authorization/token'
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/x-www-form-urlencoded',
}

data = {
    'code': code,
    'client_id': client_id,
    'client_secret': secret_key,
    'redirect_uri': redirect_uri,
    'grant_type': 'authorization_code',
}

response = requests.post(url, headers=headers, data=data)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'email': 'ashishkamble0018@gmail.com', 'exchanges': ['BSE', 'CDS', 'NSE', 'NFO', 'BFO', 'BCD'], 'products': ['OCO', 'D', 'CO', 'I'], 'broker': 'UPSTOX', 'user_id': 'FH2963', 'user_name': 'ASHISH BALAJI KAMBLE', 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'user_type': 'individual', 'poa': False, 'ddpi': False, 'is_active': True, 'access_token': 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiJGSDI5NjMiLCJqdGkiOiI2ODIzODAxMzg2OTVhYjdiMzczNWI3YTgiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6ZmFsc2UsImlhdCI6MTc0NzE1NzAxMSwiaXNzIjoidWRhcGktZ2F0ZXdheS1zZXJ2aWNlIiwiZXhwIjoxNzQ3MTczNjAwfQ.YZ0UxgI9mWeJQEo7TwGyrvRdrzEGeEDtE0MWchriE5E', 'extended_token': None}

# %%
access_token = response.json()['access_token']

# %%
import requests

url = 'https://api.upstox.com/v2/user/profile'
headers = {
    'Accept': 'application/json',
    'Authorization': f'Bearer {access_token}'
}
response = requests.get(url, headers=headers)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'success', 'data': {'email': 'ashishkamble0018@gmail.com', 'exchanges': ['BSE', 'CDS', 'NSE', 'NFO', 'BFO', 'BCD'], 'products': ['OCO', 'D', 'CO', 'I'], 'broker': 'UPSTOX', 'user_id': 'FH2963', 'user_name': 'ASHISH BALAJI KAMBLE', 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'user_type': 'individual', 'poa': False, 'ddpi': False, 'is_active': True}}

# %%
import pandas as pd

# %%
scripts = pd.read_csv('https://assets.upstox.com/market-quote/instruments/exchange/NSE.csv.gz')
scripts
# Out:
#             instrument_key  exchange_token       tradingsymbol  \
# 0             NCD_FO|14291           14291  USDINR2553081.25PE
# 1             NCD_FO|14292           14292  EURINR2553087.25CE
# 2             NCD_FO|14293           14293  EURINR2553087.25PE
# 3             NCD_FO|14294           14294     JPYINR26MAR61CE
# 4             NCD_FO|14290           14290  USDINR2553081.25CE
# ...                    ...             ...                 ...
# 59980  NSE_EQ|INE08S201019           17627                YCCL
# 59981  NSE_EQ|INF109KC1V59            3001          BSE500IETF
# 59982         NSE_FO|50244           50244      BSE25MAY6600PE
# 59983         NSE_FO|50243           50243      BSE25MAY6600CE
# 59984  NSE_EQ|INE818A01017           13598               SELAN
#
#                          name  last_price      expiry   strike  tick_size  \
# 0                      USDINR      0.0025  2025-05-30    81.25       0.25
# ...

# %%
scripts_json = pd.read_json('https://assets.upstox.com/market-quote/instruments/exchange/complete.json.gz')
scripts_json
# Out:
#        weekly segment      name exchange        expiry instrument_type  \
# 0         1.0  NCD_FO    USDINR      NSE  1.748630e+12              PE
# 1         1.0  NCD_FO    EURINR      NSE  1.748630e+12              CE
# 2         1.0  NCD_FO    EURINR      NSE  1.748630e+12              PE
# 3         0.0  NCD_FO    JPYINR      NSE  1.774636e+12              CE
# 4         1.0  NCD_FO    USDINR      NSE  1.748630e+12              CE
# ...       ...     ...       ...      ...           ...             ...
# 99023     0.0  BSE_FO    BANKEX      BSE  1.750790e+12              CE
# 99024     0.0  BSE_FO    BANKEX      BSE  1.750790e+12              PE
# 99025     1.0  BSE_FO    SENSEX      BSE  1.747161e+12              PE
# 99026     0.0  BSE_FO    BANKEX      BSE  1.750790e+12              PE
# 99027     0.0  BSE_FO  SENSEX50      BSE  1.750790e+12              CE
#
#       asset_symbol underlying_symbol  instrument_key  lot_size  ...  \
# ...

# %%
def getinstrumentkey(symbol):
    return scripts[scripts['tradingsymbol'] == symbol]['instrument_key']

# %%
print(getinstrumentkey('ADANIENT'))
# Out:
# 53867    NSE_EQ|INE423A01024
# Name: instrument_key, dtype: object

# %%
import requests

url = 'https://api.upstox.com/v3/historical-candle/NSE_EQ|INE062A01020/minutes/1/2025-01-02/2025-01-01'
headers = {
    'Accept': 'application/json'
}

response = requests.get(url, headers=headers)

# Check the response status
if response.status_code == 200:
    # Do something with the response data (e.g., print it)
    print(response.json())
else:
    # Print an error message if the request was not successful
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'status': 'success', 'data': {'candles': [['2025-01-02T15:29:00+05:30', 802.05, 802.3, 802.0, 802.25, 64888, 0], ['2025-01-02T15:28:00+05:30', 802.05, 802.2, 801.5, 802.0, 101459, 0], ['2025-01-02T15:27:00+05:30', 802.05, 802.35, 801.8, 802.05, 81304, 0], ['2025-01-02T15:26:00+05:30', 802.05, 802.3, 801.9, 802.3, 98383, 0], ['2025-01-02T15:25:00+05:30', 801.15, 802.35, 801.05, 802.1, 147082, 0], ['2025-01-02T15:24:00+05:30', 801.2, 801.9, 801.1, 801.1, 57748, 0], ['2025-01-02T15:23:00+05:30', 801.4, 801.65, 801.0, 801.45, 62960, 0], ['2025-01-02T15:22:00+05:30', 801.4, 801.55, 800.85, 801.35, 125231, 0], ['2025-01-02T15:21:00+05:30', 801.5, 801.65, 801.35, 801.35, 54177, 0], ['2025-01-02T15:20:00+05:30', 801.65, 802.05, 801.45, 801.55, 112433, 0], ['2025-01-02T15:19:00+05:30', 801.0, 801.95, 800.9, 801.65, 85627, 0], ['2025-01-02T15:18:00+05:30', 800.8, 801.35, 800.75, 801.0, 66528, 0], ['2025-01-02T15:17:00+05:30', 801.1, 801.25, 800.8, 800.8, 40420, 0], ['2025-01-02T15:16:00+05:30
# ...

# %%
def convert_date(row):
    return datetime.fromisoformat(row.datetime).strftime('%Y-%m-%d %H:%M:%S')

# %%
def getdata(symbol, interval,date_from, date_to):
    ins_key = getinstrumentkey(symbol)
    url = f'https://api.upstox.com/v3/historical-candle/{ins_key}/{interval}/{date_to}/{date_from}'
    headers = {
        'Accept': 'application/json'
    }

    response = requests.get(url, headers=headers)

    # Check the response status
    if response.status_code == 200:
        # Do something with the response data (e.g., print it)
        print(response.json())
    else:
        # Print an error message if the request was not successful
        print(f"Error: {response.status_code} - {response.text}")
        data = pd.DataFrame.from_dict(response.json()['data']['candles'])
        cols = ['datetime', 'high', 'low', 'close', 'volume', 'open interest']
        data.columns = cols
        data['datetime'] = data.apply(convert_date, axis = 1)
        data['datetime'] = pd.to_datetime(data['datetime'])
        return data # This line was incorrectly indented

# The following code was outside the function and incorrectly indented
#headers = {
#    'Accept': 'application/json'
#}
#
#response = requests.get(url, headers=headers)
#
## Check the response status
#if response.status_code == 200:
#    # Do something with the response data (e.g., print it)
#    print(response.json())
#else:
#    # Print an error message if the request was not successful
#    print(f"Error: {response.status_code} - {response.text}")
#    data = pd.DataFrame.from_dict(response.json()['data']['candles'])
#    cols = ['datetime', 'high', 'low', 'close', 'volume', 'open interest']
#    data.columns = cols
#    data['datetime'] = data.apply(convert_date, axis = 1)
#    data['datetime'] = pd.to_datetime(data['datetime'])
#    return data #This line had an extra indent
